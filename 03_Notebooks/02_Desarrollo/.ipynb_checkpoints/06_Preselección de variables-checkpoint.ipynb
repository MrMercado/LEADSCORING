# %% [markdown]
# # PLANTILLA PRESELECCIÓN DE VARIABLES

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/esteb/Escritorio/carpeta/Estudios/DS4B/03_MACHINE_LEARNING/08_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## MÉTODOS SUPERVISADOS

# %% [markdown]
# ### Preparar x e y

# %%
target = 'compra'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %% [markdown]
# ### Mutual Information

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 20

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### Recursive Feature Elimination

# %% [markdown]
# #### Instanciar

# %%
rfe = RFE(estimator = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, enable_categorical=False,
#                             eval_metric='auc', gamma=None, gpu_id=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_delta_step=None,
#                             max_depth=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, n_estimators=100,
#                             n_jobs=-1, num_parallel_tree=None, predictor=None,
#                             random_state=None, reg_alpha=None, reg_lambda=None,
#                             scale_pos_weight=None, subsample=None,
#                             tree_method=None, use_label_encoder=False,
#                             validate_parameters=None, verbosity=None))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %% [markdown]
# #### Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### Permutation Importance

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')

xgb = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc')

xgb.fit(x,y)

permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)

# %% [markdown]
# #### Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,20));

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 6

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ## SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
x_preseleccionado = x_mi
# x_preseleccionado = x_rfe
# x_preseleccionado = x_per

# %% [markdown]
# ## MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### Correlación

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
cor_finales.var1.value_counts()
# Out:
# resultado_campana_anterior_oe_ss          11
# variacion_tasa_empleo_bin_ss               8
# euribor3m_qt                               7
# euribor3m_qt_mms                           7
# euribor3m_yeo_rs                           6
# euribor3m_qt_ss                            6
# euribor3m_disc_cs                          6
# euribor3m_qt_rs                            5
# euribor3m_disc_cs_rs                       5
# edad_yeo_mms                               5
# variacion_tasa_empleo_bin_rs               5
# resultado_campana_anterior_oe              5
# euribor3m_yeo_mms                          5
# euribor3m_disc_cs_ss                       4
# num_dias_ultimo_contacto_disc_ds_mms       4
# variacion_tasa_empleo_bin_mms              4
# edad_yeo_rs                                4
# estado_civil_single                        4
# euribor3m_disc_cs_mms                      3
# num_contactos_esta_campana_disc_ds_rs      3
# num_contactos_esta_campana_disc_ds_ss      3
# euribor3m_yeo_ss                           3
# num_dias_ultimo_contacto_disc_ds           3
# resultado_campana_anterior_oe_mms          3
# edad_yeo                                   3
# euribor3m_yeo                              2
# formacion_oe_mms                           2
# variacion_tasa_empleo_bin                  2
# resultado_campana_anterior_oe_rs           2
# consumo_no                                 2
# num_contactos_esta_campana_disc_cs         2
# edad_yeo_ss                                2
# trabajo_te                                 1
# estado_civil_married                       1
# mes_te                                     1
# num_dias_ultimo_contacto_disc_ds_rs        1
# edad_qt                                    1
# impago_no                                  1
# trabajo_te_ss                              1
# hipoteca_no                                1
# num_contactos_esta_campana_disc_ds_mms     1
# formacion_oe_ss                            1
# num_contactos_esta_campana_disc_cs_rs      1
# estado_civil_divorced                      1
# formacion_oe_rs                            1
# edad_qt_rs                                 1
# num_dias_ultimo_contacto_disc_ds_ss        1
# Name: var1, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
cor_finales.head(50)
# Out:
#                                       var1  \
# 1214      num_dias_ultimo_contacto_disc_ds
# 1280    num_contactos_esta_campana_disc_cs
# 2587                       formacion_oe_rs
# 3393                       formacion_oe_ss
# 4185                       euribor3m_qt_ss
# 1729                      formacion_oe_mms
# 1676                          euribor3m_qt
# 2495                      euribor3m_qt_mms
# 1703                      formacion_oe_mms
# 2402                     euribor3m_yeo_mms
# 3551                         trabajo_te_ss
# 2072  num_dias_ultimo_contacto_disc_ds_mms
# 3723   num_dias_ultimo_contacto_disc_ds_ss
# 2033  num_dias_ultimo_contacto_disc_ds_mms
# 1016                            trabajo_te
# 2059  num_dias_ultimo_contacto_disc_ds_mms
# 1082                                mes_te
# 2389                     euribor3m_yeo_mms
# 1610                               edad_qt
# 463                              impago_no
# 266                            hipoteca_no
# 2312                          edad_yeo_mms
# 3157                           edad_yeo_rs
# 3183                           edad_yeo_rs
# 4028                           edad_yeo_ss
# 1467                              edad_yeo
# 3989                           edad_yeo_ss
# 2338                          edad_yeo_mms
# 3170                           edad_yeo_rs
# 2325                          edad_yeo_mms
# 1480                              edad_yeo
# 3144                           edad_yeo_rs
# 2299                          edad_yeo_mms
# 662                             consumo_no
# 1687                          euribor3m_qt
# 1661                          euribor3m_qt
# 2391                     euribor3m_yeo_mms
# 3364                       euribor3m_qt_rs
# 3223                      euribor3m_yeo_rs
# 4081                      euribor3m_yeo_ss
# 2532                      euribor3m_qt_mms
# 2506                      euribor3m_qt_mms
# 4209                       euribor3m_qt_ss
# 4196                       euribor3m_qt_ss
# 4183                       euribor3m_qt_ss
# 3050                  euribor3m_disc_cs_rs
# 3933          variacion_tasa_empleo_bin_ss
# 3114          variacion_tasa_empleo_bin_rs
# 2269         variacion_tasa_empleo_bin_mms
# 3959          variacion_tasa_empleo_bin_ss
#
#                                        var2      corr
# 1214    num_dias_ultimo_contacto_disc_ds_rs  1.000000
# 1280  num_contactos_esta_campana_disc_cs_rs  1.000000
# 2587                        formacion_oe_ss  1.000000
# 3393                           formacion_oe  1.000000
# 4185                           euribor3m_qt  1.000000
# 1729                        formacion_oe_rs  1.000000
# 1676                        euribor3m_qt_rs  1.000000
# 2495                           euribor3m_qt  1.000000
# 1703                           formacion_oe  1.000000
# 2402                       euribor3m_yeo_ss  1.000000
# 3551                          trabajo_te_rs  1.000000
# 2072    num_dias_ultimo_contacto_disc_ds_ss  1.000000
# 3723       num_dias_ultimo_contacto_disc_ds  1.000000
# 2033       num_dias_ultimo_contacto_disc_ds  1.000000
# 1016                          trabajo_te_rs  1.000000
# 2059    num_dias_ultimo_contacto_disc_ds_rs  1.000000
# 1082                              mes_te_rs  1.000000
# 2389                       euribor3m_yeo_rs  1.000000
# 1610                             edad_qt_rs  1.000000
# 463                          impago_unknown  0.999843
# 266                            hipoteca_yes  0.951505
# 2312                            edad_qt_mms  0.932047
# 3157                            edad_qt_mms  0.932047
# 3183                             edad_qt_ss  0.932047
# 4028                             edad_qt_ss  0.932047
# 1467                            edad_qt_mms  0.932047
# 3989                                edad_qt  0.932047
# 2338                             edad_qt_ss  0.932047
# 3170                             edad_qt_rs  0.932047
# 2325                             edad_qt_rs  0.932047
# 1480                             edad_qt_rs  0.932047
# 3144                                edad_qt  0.932047
# 2299                                edad_qt  0.932047
# 662                             consumo_yes  0.913681
# 1687                       euribor3m_yeo_ss  0.864311
# 1661                      euribor3m_yeo_mms  0.864311
# 2391                        euribor3m_qt_rs  0.864311
# 3364                       euribor3m_yeo_rs  0.864311
# 3223                       euribor3m_qt_mms  0.864311
# 4081                        euribor3m_qt_rs  0.864311
# 2532                       euribor3m_yeo_ss  0.864311
# 2506                      euribor3m_yeo_mms  0.864311
# 4209                       euribor3m_yeo_rs  0.864311
# 4196                      euribor3m_yeo_mms  0.864311
# 4183                          euribor3m_yeo  0.864311
# 3050           variacion_tasa_empleo_bin_ss  0.862815
# 3933                  euribor3m_disc_cs_mms  0.862815
# 3114                   euribor3m_disc_cs_ss  0.862815
# 2269                   euribor3m_disc_cs_ss  0.862815
# 3959                   euribor3m_disc_cs_ss  0.862815

# %% [markdown]
# #### Filtrar variables

# %% [markdown]
# Meter en una lista las que queramos descartar por alta correlacion y eliminarlas.

# %%
a_eliminar_corr = ['euribor3m_qt', 'euribor3m_yeo_rs']

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['euribor3m_qt_mms',
#  'euribor3m_yeo',
#  'euribor3m_yeo_mms',
#  'euribor3m_qt_rs',
#  'euribor3m_qt_ss',
#  'euribor3m_yeo_ss',
#  'num_dias_ultimo_contacto_disc_ds',
#  'num_dias_ultimo_contacto_disc_ds_mms',
#  'variacion_tasa_empleo_bin_mms',
#  'num_dias_ultimo_contacto_disc_ds_ss',
#  'variacion_tasa_empleo_bin',
#  'variacion_tasa_empleo_bin_ss',
#  'resultado_campana_anterior_oe_ss',
#  'num_dias_ultimo_contacto_disc_ds_rs',
#  'variacion_tasa_empleo_bin_rs',
#  'resultado_campana_anterior_oe_rs',
#  'resultado_campana_anterior_oe_mms',
#  'resultado_campana_anterior_oe']

# %% [markdown]
# ## GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)
